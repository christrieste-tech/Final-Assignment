# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# Summary of Data Science tools and Ecosystem.

# %% [markdown]
# **Objectives:**
#
# * Jupyter Notebook
# * Scikit-learn
# * Git
# * SQL

# %% [markdown]
# Some of the popular languages that Data Scientists use are:

# %% [markdown]
# 1. Python
# 2. R
# 3. Julia

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:

# %% [markdown]
# 1. Numpy
# 2. Scikit-learn
# 3. Caret

# %% [markdown]
# | Data Science Tools |
# | --- |
# | Jupyter Notebook |
# | RStudio |
# | Git |

# %% [markdown]
# ### Examples of Evaluating Arithmetic Expressions in Python

# %%
# Simple Arithmetic Expression to Mutiply then add Integers
(3*4)+5
# Out:
# 17

# %%
# Convert 200 minutes to hours by diving by 60
# Minutes
minutes = 200

# hours (200 / 60)
hours = minutes / 60
# Print the result
print(f"{minutes} minutes equal a {hours:.2f} hours.")
# Out:
# 200 minutes igual a 3.33 hours.

# %% [markdown]
# ## Autor
# [Christiano Jorge Gomes Pinheiro]
